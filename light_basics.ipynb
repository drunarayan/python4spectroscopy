# %% [markdown]
# # [Light Wavelength Frequency and Speed](https://openstax.org/books/astronomy-2e/pages/5-1-the-behavior-of-light)

# %% [markdown]
# ![light basics](https://openstax.org/apps/archive/20240625.161426/resources/8caecaac580f639ebf6ba550db228a684da01ca6)

# %% [markdown]
# $c = \lambda f$ OR $\lambda = {{c}\over{f}}$
#
# where $c$ is the *speed* of the wave in $m\over{s}$,
#
# $\lambda$ is *wavelength* in $m$, and
#
# $f$ is in ${hz}$ which has units of $1\over{s}$

# %% [markdown]
# <div class="alert alert-info">🔵 What is the wavelength of visible light that has a frequency of  5.66×10^14 Hz
#  ? Provide your answer by creating variables and calculating below?</div>

# %%
f = 5.66e14 #hz
c = 3e8 #m/s
w = c/f
result = f'The wavelength of visible light that has a frequency of 5.66×10^14 Hz is {w:1.2e} m'
print(result)
# Out:
# The wavelength of visible light that has a frequency of 5.66×10^14 Hz is 5.30e-07 m

# %% [markdown]
# <div class="alert alert-info">🔵“Tidal waves,” or tsunamis, are waves caused by earthquakes that travel rapidly through the ocean. If a tsunami travels at the speed of 600 km/h (speed of an airliner) and approaches a shore at a rate of one wave crest every 15 min (4 waves/h), what would be the distance between those wave crests at sea in km?</div>

# %%
c = 600e3/3600 #m/s
f = 4/3600 #hz
w = c/f
result = f'the distance between those wave crests at sea is {w/1000:.0f} km'
print(result)
# Out:
# the distance between those wave crests at sea is 150 km

# %% [markdown]
# ![Electromagnetic Spectrum falling on Earth](https://openstax.org/apps/archive/20240130.204924/resources/fd686395fdb767eb21ed9f677d202e5b639293db)

# %% [markdown]
# ![Screenshot 2024-07-18 at 6.52.56 PM.png](attachment:d8831567-d427-4bd1-8d34-f8d39e4701b7.png)

# %% [markdown]
# ![Screenshot 2024-07-18 at 6.55.09 PM.png](attachment:81309d62-5a05-45cd-88a6-ccac4bb43409.png)
